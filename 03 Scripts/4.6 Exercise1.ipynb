# %%
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
# Define a dictionary containing January 2020 data

# %%
data1 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
    'purchased_meat':[0, 13, 3, 4],
    'purchased_alcohol':[1, 2, 10, 0],
    'purchased_snacks':[10, 5, 1, 7]}

# %%
# Define a dictionary containing February 2020 data

# %%
data2 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Feb-20', 'Feb-20', 'Feb-20', 'Feb-20'],
    'purchased_meat':[0, 10, 5, 3],
    'purchased_alcohol':[2, 4, 14, 0],
    'purchased_snacks':[15, 3, 2, 6]}

# %%
#Convert the dictionary into dataframe

# %%
df = pd.DataFrame(data1 , index = [0 , 1, 2, 3])

# %%
df_1 = pd.DataFrame(data2 , index = [0 , 1, 2, 3])

# %%
df
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7

# %%
df_1
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
frames = [df , df_1]

# %%
df_concat = pd.concat(frames)

# %%
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
df_concat = pd.concat(frames , axis = 1)

# %%
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
data3 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
    'days_purchased_on':[0, 10, 4, 1]}

df_2 = pd.DataFrame(data3,index=[0, 1, 2, 3])

# %%
df_merged = df.merge(df_2, on = 'customer_id')

# %%
df_merged
# Out:
#   customer_id month_x  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#   month_y  days_purchased_on
# 0  Jan-20                  0
# 1  Jan-20                 10
# 2  Jan-20                  4
# 3  Jan-20                  1

# %%
df_merged = df.merge(df_2, on = ['customer_id' , 'month'])

# %%
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on
# 0                  0
# 1                 10
# 2                  4
# 3                  1

# %%
df_merged = df.merge(df_2, on = ['customer_id', 'month'], indicator = True)

# %%
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on _merge
# 0                  0   both
# 1                 10   both
# 2                  4   both
# 3                  1   both

# %%
# Test merge without overwriting

pd.merge(df,df_2, on = ['customer_id', 'month'], indicator = True)
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on _merge
# 0                  0   both
# 1                 10   both
# 2                  4   both
# 3                  1   both

# %%
#  Importing orders_products_prior.csv

# %%
path = r'C:\Users\84sat\OneDrive\Desktop\CAREER FOUNDRY\4 Python Practice\1 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\84sat\\OneDrive\\Desktop\\CAREER FOUNDRY\\4 Python Practice\\1 Instacart Basket Analysis'

# %%
df_prods_ords_prior = pd.read_csv(os.path.join(path , '02 Data' , 'Original Data' , 'orders_products_prior.csv') , index_col = False )

# %%
df_prods_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#  Importing ords_checked file

# %%
df_ords = pd.read_csv(os.path.join(path , '02 Data' , 'Prepared Data' , 'orders_checked.csv') , index_col = False )

# %%
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  user_id   \
# 0                   2                  8                     NaN         1
# 1                   3                  7                    15.0         1
# 2                   3                 12                    21.0         1
# 3                   4                  7                    29.0         1
# 4                   4                 15                    28.0         1
#
#    first_order
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False

# %%
# Drrop unnamed coloumns from df_orders Dataframe

# %%
df_ords = df_ords.drop(columns =['Unnamed: 0.1' , 'Unnamed: 0'])

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  user_id   first_order
# 0                     NaN         1         True
# 1                    15.0         1        False
# 2                    21.0         1        False
# 3                    29.0         1        False
# 4                    28.0         1        False

# %%
# Merging df_ords and df_prods_ords_prior Dataframes

# %%
df_merged_Large = df_ords.merge(df_prods_ords_prior, on = 'order_id' , indicator = True)

# %%
df_merged_Large.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  user_id   first_order  product_id  \
# 0                     NaN         1         True         196
# 1                     NaN         1         True       14084
# 2                     NaN         1         True       12427
# 3                     NaN         1         True       26088
# 4                     NaN         1         True       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_merged_Large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# Export data to pkl

# %%
df_merged_Large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
